# %% [markdown]
# <a href="https://colab.research.google.com/github/Bharath2026/Data-Handling-and-visualization/blob/main/Spatial_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

world=gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.plot()
plt.title('World Countries')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
import folium
from folium import IFrame

# Bengaluru coordinates
bengaluru_coords = (12.9716, 77.5946)

# Create a map centered around Bengaluru
map_bengaluru = folium.Map(location=bengaluru_coords, zoom_start=12)

# Add markers with descriptions and images
locations = [
    {
        'name': 'Location 1',
        'coords': (12.9750, 77.6206),
        'description': 'The Vidhana Soudha in Bangalore, India - the seat of the state legislature of Karnataka',
        'image': 'https://www.istockphoto.com/photo/vidhana-soudha-in-bangalore-india-the-seat-of-the-state-legislature-of-karnataka-gm1433555981-475435161?utm_campaign=srp_photos_top&utm_content=https%3A%2F%2Funsplash.com%2Fs%2Fphotos%2Fbengaluru&utm_medium=affiliate&utm_source=unsplash&utm_term=bengaluru%3A%3A%3A'
    },
    {
        'name': 'Location 2',
        'coords': (12.9345, 77.5365),
        'description': 'The beautiful Maharajahs Palace in Mysore, Karnataka, India',
        'image': 'https://www.istockphoto.com/photo/maharajahs-palace-in-mysore-gm614243374-106234375?utm_campaign=srp_photos_top&utm_content=https%3A%2F%2Funsplash.com%2Fs%2Fphotos%2Fbengaluru-famous-place&utm_medium=affiliate&utm_source=unsplash&utm_term=bengaluru+famous+place%3A%3A%3A'
    }
]

for loc in locations:
    # Create HTML for the popup including description and image
    html = f'<h3>{loc["name"]}</h3><p>{loc["description"]}</p><img src="{loc["image"]}" alt="Location Image" style="width:200px;height:150px;">'
    iframe = folium.IFrame(html=html, width=300, height=200)
    folium.Marker(
        location=loc['coords'],
        popup=folium.Popup(iframe, max_width=300),
        icon=folium.Icon(color='blue')
    ).add_to(map_bengaluru)
map_bengaluru.save('bengaluru_map_with_markers.html')
map_bengaluru
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_20af4209995139c739f82c1c12832cb8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_20af4209995139c739f82c1c12832cb8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_20af4209995139c739f82c1c12832cb8 = L.map(
#                 &quot;map_20af4209995139c739f82c1c12832cb8&quot;,
#                 {
#                     center: [12.9716, 77.5946],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_979f07e681b2152fc4c8877605bed489 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_20af4209995139c739f82c1c12832cb8);
#
#
#             var marker_e57ee81909649425b3bdb38ab4fcee8a = L.marker(
#                 [12.975, 77.6206],
#                 {}
#             ).addTo(map_20af4209995139c739f82c1c12832cb8);
#
#
#             var icon_ced74209645277562acdd7bfb8e62718 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e57ee81909649425b3bdb38ab4fcee8a.setIcon(icon_ced74209645277562acdd7bfb8e62718);
#
#
#         var popup_f1ebf8581187d9462d03ac6857472145 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var i_frame_2c833b58b90b49bd7acdfb396c0d1744 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;200&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_f1ebf8581187d9462d03ac6857472145.setContent(i_frame_2c833b58b90b49bd7acdfb396c0d1744);
#
#
#
#         marker_e57ee81909649425b3bdb38ab4fcee8a.bindPopup(popup_f1ebf8581187d9462d03ac6857472145)
#         ;
#
#
#
#
#             var marker_8cc713e086b4a59a1743d049e2b1b0bb = L.marker(
#                 [12.9345, 77.5365],
#                 {}
#             ).addTo(map_20af4209995139c739f82c1c12832cb8);
#
#
#             var icon_49819dcfc734ad73c5a40e35dc4636a9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8cc713e086b4a59a1743d049e2b1b0bb.setIcon(icon_49819dcfc734ad73c5a40e35dc4636a9);
#
#
#         var popup_6e6ee8a6b87253db583a7784d1ce849a = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var i_frame_f8c9594cd42c6c4396e3ac1e344746ab = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;200&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_6e6ee8a6b87253db583a7784d1ce849a.setContent(i_frame_f8c9594cd42c6c4396e3ac1e344746ab);
#
#
#
#         marker_8cc713e086b4a59a1743d049e2b1b0bb.bindPopup(popup_6e6ee8a6b87253db583a7784d1ce849a)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
